# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
class Circuit: 
    '''

    Class for that generates N-dimensional gates acting of arbitatry qubit.
    Gates - Pauli Rotation, H, X, RY, RX, RZ and CNOT.
    Also generates the zero N-dimensional state.

    '''

    def __init__(self, nqubits):
        self.nqubits = nqubits
        self.σx = np.array([[0.0,1.0],[1.0,0.0]]);
        self.σz = np.array([[1.0,0.0],[0.0,-1.0]]);
        self.σy = np.array([[0.0,-1j],[1.j,0.0]]);
        self.σ = np.array([np.eye(2), self.σx, self.σy, self.σz]);
        self.d = 2**nqubits
        self.H = np.array([[1,1],[1,-1]])/np.sqrt(2.0)

    def zero_state(self):
        ψ = np.zeros((self.d,))
        ψ[0] = 1.0
        return ψ

    def pauli_rotation(self, state, σ, θ, qubit):
        θ = np.asarray(θ).reshape(-1,1,1)/2.0
        M = θ.shape[0]
        U = np.cos(θ) * np.eye(2) - 1j * np.sin(θ) * σ
        Usame = U[:,[0,1],[0,1]].reshape(-1,2)
        Uoppo = U[:,[0,1],[1,0]].reshape(-1,2)
        di = 2**qubit
        dj = 2**(self.nqubits - qubit - 1)
        state = state.reshape(-1, dj, 2, di)
        state = Usame.reshape(M, 1, 2, 1) * state \
              + Uoppo.reshape(M, 1, 2, 1) * state[:, :, [1,0], :]
        if state.shape[0] == 1:
            return state.flatten()
        else:
            return state.reshape(-1, self.d)

    def h(self, state, qubit):
        di = 2**qubit
        s = state.shape
        state = state.reshape(-1, 2, di)
        return np.einsum('mjl,ji->mil', state, self.H).reshape(s)

    def x(self, state, qubit):
        di = 2**qubit
        s = state.shape
        state = state.reshape(-1, 2, di)
        return state[:,[1,0],:].reshape(s)

    def ry(self, state, θ, qubit):
        return self.pauli_rotation(state, self.σy, θ, qubit)

    def rx(self, state, θ, qubit):
        return self.pauli_rotation(state, self.σx, θ, qubit)

    def rz(self, state, θ, qubit):
        return self.pauli_rotation(state, self.σz, θ, qubit)

    def cx(self, state, qubit, target):
        assert self.nqubits >= 2
        assert 0 <= qubit <= self.nqubits
        assert 0 <= target <= self.nqubits
        assert target != qubit
        i = min(qubit, target)
        j = max(qubit, target)
        di = 2**i
        dj = 2**(j-i-1)
        dk = 2**(self.nqubits - j - 1)
        s = state.shape
        state = state.reshape(-1, 2, dj, 2, di).copy()
        if qubit > target:
            state[:,1,:,[1,0],:] = state[:,1,:,[0,1],:]
        else:
            state[:,[1,0],:,1,:] = state[:,[0,1],:,1,:]
        return state.reshape(s)

# %%
from numpy import pi as π
def coding_bits(b):
    c = [b[n:n+5] for n,i in enumerate(b) if n%5==0]
    c_p=[]
    coding_0=[]
    for i in range(len(c)):
        for j in c[i]:
            c_p.append(str(j))
    np.asarray(c_p)
    c = [c_p[n:n+5] for n,i in enumerate(c_p) if n%5==0]
    for i in c:
        coding_0.append(''.join(i))
    return coding_0

class CircuitConversor:
    
    '''
    ## Decodes strings of bits into a an array representating the state.
    __call__ function takes in a string of bits and returns the state and the cost to apply operations.
    '''

    def __init__(self, nqubits, nparameters):
        self.gates = gates = {}
        for n, suffix in enumerate(['00','01','10','11']):
            angle = π / (2**n)
            gates['000'+suffix] = (self.make_h(), 1.0)
            gates['001'+suffix] = (self.make_cx(), 2.0)
            gates['010'+suffix] = (self.make_id(), 0.0)
            gates['011'+suffix] = (self.make_rx(angle), 1.0)
            gates['100'+suffix] = (self.make_rz(angle), 1.0)
            gates['101'+suffix] = (self.make_id(), 0.0)
            gates['110'+suffix] = (self.make_id(), 0.0)
            gates['111'+suffix] = (self.make_ry(angle), 1.0)
        self.nqubits = nqubits
        self.nparameters = nparameters
        self.circuit = Circuit(nqubits)

    def __call__(self, coding_0, parameters):
        k = 0
        cost = 0
        state = self.circuit.zero_state()
        for ndx, z in enumerate(coding_bits(coding_0)):
            qubit = ndx % self.nqubits
            target = (ndx + 1) % self.nqubits
            fn, weight = self.gates[z]
            state, k = fn(state, parameters, k, qubit, target)
            cost += weight
        if k == 0 and parameters.ndim == 2:
            state = np.ones((parameters.shape[1],1)) * state.reshape(1,-1)
        return state, cost

    def make_id(self):
        def operation(state, parameters, k, qubit, target):
            return state, k
        return operation

    def make_h(self):
        def operation(state, parameters, k, qubit, target):
            return self.circuit.h(state, qubit), k
        return operation

    def make_cx(self):
        def operation(state, parameters, k, qubit, target):
            return self.circuit.cx(state, qubit, target), k
        return operation

    def make_rx(self, angle):
        def operation(state, parameters, k, qubit, target):
            ndx = k % self.nparameters
            return self.circuit.rx(state, parameters[ndx,:]*angle, qubit), k+1
        return operation

    def make_ry(self, angle):
        def operation(state, parameters, k, qubit, target):
            ndx = k % self.nparameters
            return self.circuit.ry(state, parameters[ndx,:]*angle, qubit), k+1
        return operation

    def make_rz(self, angle):
        def operation(state, parameters, k, qubit, target):
            ndx = k % self.nparameters
            return self.circuit.rz(state, parameters[ndx,:]*angle, qubit), k+1
        return operation

# %%
from sklearn.svm import SVC

class QSVM:
    '''
    Takes in the feature map we generated and outputs a classifier model and its fit.
    '''
    def __init__(self, feature_map, train_features, train_label):
        def kernel(x1, x2):
            ψ1 = feature_map(x1.T)
            ψ2 = feature_map(x2.T)
            gram = ψ1.real @ ψ2.real.T + ψ1.imag @ ψ2.imag.T
            return gram
        self.svc = SVC(kernel=kernel)
        self.svc.fit(train_features, train_label)

    def run(self):
        pass

    def predict(self, dataset_features):
        return self.svc.predict(dataset_features)

# %%
import os
import psutil
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import accuracy_score

def metricas_modelos(y_true, y_pred): 
    from sklearn.metrics import accuracy_score
    accuracy = accuracy_score(y_true, y_pred)
    return(accuracy)

def reca(y_true, y_pred):
    from sklearn.metrics import recall_score
    recall = recall_score(y_true,y_pred,average='binary')
    return(recall)

def Dataset(X, y, test_size_split=0.2):
    class_labels = [r'0', r'1']

    n_samples = np.shape(X)[0]
    training_size = int(n_samples-(n_samples*test_size_split))
    test_size =int(n_samples-training_size)
    train_sample, test_sample, train_label, test_label = \
        train_test_split(X, y, stratify=y, test_size=test_size_split, random_state=12)

    std_scale = StandardScaler().fit(train_sample)
    train_sample = std_scale.transform(train_sample)
    test_sample = std_scale.transform(test_sample)

    samples = np.append(train_sample, test_sample, axis=0)
    minmax_scale = MinMaxScaler((-1, 1)).fit(samples)
    train_sample = minmax_scale.transform(train_sample)
    test_sample = minmax_scale.transform(test_sample)

    return train_sample, train_label, test_sample, test_label

class Fitness:
    '''
    This class calculates the fitness of a single bit string and return its cost and accuracy 
    '''

    def __init__(self, nqubits, nparameters, X, y, debug=False):
        self.nqubits = nqubits
        self.nparameters = nparameters
        self.cc = CircuitConversor(nqubits, nparameters)
        self.X = X
        self.y = y
        self.debug = debug

    def __call__(self, POP):
        return self.fitness(POP)

    def fitness(self, POP):
        #Convertimos el individuo en el fenotipo (ansatz)
        training_features, training_labels, test_features, test_labels = \
            Dataset(self.X, self.y)
        
        model = QSVM(lambda parameters: self.cc(POP, parameters)[0],
                          training_features, training_labels)
        y_pred = model.predict(test_features) # 22% del computo (ver abajo line-profiler)
        acc = metricas_modelos(test_labels, y_pred) # sklearn
        rec = reca(test_labels,y_pred)
        POP=''.join(str(i) for i in POP)
        _, gates = self.cc(POP, training_features[:,[0,1]])
        if self.debug:
            print(f'String: {POP}\n -> accuracy = {acc}, gates = {gates},recall = {rec}')
        gate = gates/self.nqubits
        wc = gate + (gate*(acc**2))
        return wc, acc

# %%
from deap import base, creator, tools, algorithms
import random
def gsvm(nqubits, depth, nparameters, X, y,
         mu=100, lambda_=150, cxpb=0.7, mutpb=0.3, ngen=2000,
         use_pareto=True, verbose=True, weights=[-1.0,1.0],
         debug=True):
    bits_puerta = 5
    long_cadena = depth * nqubits * bits_puerta
    creator.create("FitnessMulti", base.Fitness, weights=weights)
    creator.create("Individual", list, fitness = creator.FitnessMulti, statistics=dict)

    toolbox = base.Toolbox()
    toolbox.register("attr_bool", random.randint, 0, 1)
    toolbox.register("Individual", tools.initRepeat, creator.Individual,
                     toolbox.attr_bool, long_cadena)
    toolbox.register("Population", tools.initRepeat, list, toolbox.Individual)
    toolbox.register('mate', tools.cxTwoPoint)
    toolbox.register('mutate', tools.mutFlipBit, indpb=0.2)
    toolbox.register('select', tools.selNSGA2)
    toolbox.register("evaluate", Fitness(nqubits, nparameters, X, y, debug=debug))

    pop = toolbox.Population(n=mu)

    stats_wc = tools.Statistics(key=lambda ind: ind.fitness.values[0])
    stats_wc.register('media',np.mean)
    stats_wc.register('std',np.std)
    stats_wc.register('max',np.max)
    stats_wc.register('min',np.min)
    stats_acc = tools.Statistics(key=lambda ind: ind.fitness.values[1])
    stats_acc.register('media',np.mean)
    stats_acc.register('std',np.std)
    stats_acc.register('max',np.max)
    stats_acc.register('min',np.min)
    mstats = tools.MultiStatistics(wc=stats_wc, acc=stats_acc)

    logbook = tools.Logbook()
    pareto = tools.ParetoFront(similar = np.array_equal)
    pop, logbook = algorithms.eaMuPlusLambda(pop, toolbox,
                                             mu, lambda_, cxpb, mutpb, ngen,
                                             stats=mstats,
                                             halloffame=pareto, verbose=verbose)
    pareto.update(pop)
    return pop, pareto, logbook

# %%
output="bank_testdata.csv"
df = pd.read_csv('bank_cleaned.csv')  

bank_data = df.sample(n=2000)

# %%
nqubits = 8
depth = 12
y = bank_data['y'].values
X = bank_data[['age','job','marital','education','default','balance','housing','loan','contact',
                'day','month','duration','campaign','pdays','previous','poutcome']].values
start = time.time()

pop, pareto, logbook = gsvm(nqubits=nqubits, depth=depth, nparameters=16,
                                    X=X, y=y, weights=[-1.0,1.0],
                                    mu=20,lambda_=10,ngen=20,mutpb=0.3,cxpb=.7)

print(f'Simulation finished after {time.time()-start} seconds')

with open(output, "w") as f:
    for ide, ind in enumerate(pareto):
        genes=''.join(str(i) for i in list(ind))
        gates, acc = ind.fitness.values
        line = f'{ide},"{genes}",{gates},{acc}'
        f.write(line)
        f.write('\n')
# Out:
# String: ...
#  -> accuracy = 0.69, gates = 68.0,recall = 0.665
# String: ...
#  -> accuracy = 0.7375, gates = 74.0,recall = 0.675
# String: ...
#  -> accuracy = 0.585, gates = 69.0,recall = 0.575
# String: ...
#  -> accuracy = 0.6675, gates = 67.0,recall = 0.585
# String: ...
#  -> accuracy = 0.6275, gates = 77.0,recall = 0.64
# String: ...
#  -> accuracy = 0.6025, gates = 65.0,recall = 0.59
# String: ...
#  -> accuracy = 0.5925, gates = 76.0,recall = 0.565
# String: ...
#  -> accuracy = 0.6475, gates = 63.0,recall = 0.6
# String: ...
#  -> accuracy = 0.6575, gates = 72.0,recall = 0.6
# String: ...
#  -> accuracy = 0.725, gates = 70.0,recall = 0.635
# String: ...
#  -> accuracy = 0.675, gates = 63.0,recall = 0.535
# String: ...
#  -> accuracy = 0.755, gates = 64.0,recall = 0.725
# String: ...
#  -> accuracy = 0.6925, gates = 82.0,recall = 0.64
# String: ...
#  -> accuracy = 0.5625, gates = 64.0,recall = 0.52
# String: ...
#  -> accuracy = 0.6975, gates = 72.0,recall = 0.625
# String: ...
#  -> accuracy = 0.655, gates = 64.0,recall = 0.61
# String: ...
#  -> accuracy = 0.6725, gates = 62.0,recall = 0.64
# String: ...
#  -> accuracy = 0.6425, gates = 69.0,recall = 0.585
# String: ...
#  -> accuracy = 0.6125, gates = 73.0,recall = 0.57
# String: ...
#  -> accuracy = 0.655, gates = 64.0,recall = 0.605
#    	      	                           acc                           	                      wc
#    	      	---------------------------------------------------------	----------------------------------------------
# gen	nevals	gen	max  	media   	min   	nevals	std      	gen	max    	media  	min    	nevals	std
# 0  	20    	0  	0.755	0.657625	0.5625	20    	0.0498841	0  	15.1655	12.3602	10.5312	20    	1.1437
# String: ...
#  -> accuracy = 0.6825, gates = 60.0,recall = 0.695
# String: ...
#  -> accuracy = 0.6825, gates = 62.0,recall = 0.62
# String: ...
#  -> accuracy = 0.685, gates = 78.0,recall = 0.635
# String: ...
#  -> accuracy = 0.76, gates = 71.0,recall = 0.69
# String: ...
#  -> accuracy = 0.745, gates = 60.0,recall = 0.75
# String: ...
#  -> accuracy = 0.5975, gates = 67.0,recall = 0.55
# String: ...
#  -> accuracy = 0.77, gates = 72.0,recall = 0.7
# String: ...
#  -> accuracy = 0.64, gates = 76.0,recall = 0.58
# String: ...
#  -> accuracy = 0.6775, gates = 77.0,recall = 0.615
# String: ...
#  -> accuracy = 0.6325, gates = 62.0,recall = 0.6
# 1  	10    	1  	0.77 	0.681875	0.5625	10    	0.0554294	1  	15.1655	12.2108	10.5312	10    	1.35226
# String: ...
#  -> accuracy = 0.665, gates = 65.0,recall = 0.62
# String: ...
#  -> accuracy = 0.605, gates = 72.0,recall = 0.58
# String: ...
#  -> accuracy = 0.675, gates = 73.0,recall = 0.63
# String: ...
#  -> accuracy = 0.7575, gates = 67.0,recall = 0.725
# String: ...
#  -> accuracy = 0.7, gates = 72.0,recall = 0.685
# String: ...
#  -> accuracy = 0.6025, gates = 58.0,recall = 0.525
# String: ...
#  -> accuracy = 0.635, gates = 77.0,recall = 0.625
# String: ...
#  -> accuracy = 0.7875, gates = 78.0,recall = 0.81
# String: ...
#  -> accuracy = 0.685, gates = 61.0,recall = 0.655
# String: ...
#  -> accuracy = 0.5875, gates = 67.0,recall = 0.53
# 2  	10    	2  	0.7875	0.68925 	0.5625	10    	0.0647355	2  	15.7965	12.2358	9.8818 	10    	1.52559
# String: ...
#  -> accuracy = 0.6775, gates = 60.0,recall = 0.61
# String: ...
#  -> accuracy = 0.67, gates = 66.0,recall = 0.61
# String: ...
#  -> accuracy = 0.5975, gates = 62.0,recall = 0.5
# String: ...
#  -> accuracy = 0.61, gates = 80.0,recall = 0.62
# String: ...
#  -> accuracy = 0.7125, gates = 73.0,recall = 0.65
# String: ...
#  -> accuracy = 0.66, gates = 57.0,recall = 0.59
# String: ...
#  -> accuracy = 0.6175, gates = 69.0,recall = 0.58
# String: ...
#  -> accuracy = 0.625, gates = 64.0,recall = 0.57
# String: ...
#  -> accuracy = 0.7025, gates = 66.0,recall = 0.675
# String: ...
#  -> accuracy = 0.6575, gates = 51.0,recall = 0.585
# 3  	10    	3  	0.7875	0.702625	0.6025	10    	0.0494436	3  	15.7965	12.1134	9.13095	10    	1.69177
# String: ...
#  -> accuracy = 0.6975, gates = 55.0,recall = 0.625
# String: ...
#  -> accuracy = 0.72, gates = 54.0,recall = 0.76
# String: ...
#  -> accuracy = 0.57, gates = 58.0,recall = 0.605
# String: ...
#  -> accuracy = 0.58, gates = 58.0,recall = 0.555
# String: ...
#  -> accuracy = 0.64, gates = 66.0,recall = 0.595
# String: ...
#  -> accuracy = 0.715, gates = 83.0,recall = 0.675
# String: ...
#  -> accuracy = 0.6675, gates = 61.0,recall = 0.65
# String: ...
#  -> accuracy = 0.6875, gates = 62.0,recall = 0.69
# String: ...
#  -> accuracy = 0.5875, gates = 67.0,recall = 0.52
# String: ...
#  -> accuracy = 0.7175, gates = 64.0,recall = 0.685
# 4  	10    	4  	0.7875	0.69875 	0.57  	10    	0.0602624	4  	15.7965	11.7421	9.13095	10    	1.83959
# String: ...
#  -> accuracy = 0.72, gates = 62.0,recall = 0.685
# String: ...
#  -> accuracy = 0.6025, gates = 59.0,recall = 0.575
# String: ...
#  -> accuracy = 0.62, gates = 69.0,recall = 0.53
# String: ...
#  -> accuracy = 0.6275, gates = 63.0,recall = 0.65
# String: ...
#  -> accuracy = 0.7325, gates = 70.0,recall = 0.63
# String: ...
#  -> accuracy = 0.6825, gates = 69.0,recall = 0.7
# String: ...
#  -> accuracy = 0.65, gates = 59.0,recall = 0.69
# String: ...
#  -> accuracy = 0.7325, gates = 62.0,recall = 0.69
# String: ...
#  -> accuracy = 0.745, gates = 64.0,recall = 0.71
# String: ...
#  -> accuracy = 0.6975, gates = 55.0,recall = 0.625
# 5  	10    	5  	0.7875	0.700375	0.57  	10    	0.0606232	5  	15.7965	11.5218	9.13095	10    	1.72935
# String: ...
#  -> accuracy = 0.765, gates = 59.0,recall = 0.735
# String: ...
#  -> accuracy = 0.59, gates = 57.0,recall = 0.565
# String: ...
#  -> accuracy = 0.7775, gates = 66.0,recall = 0.765
# String: ...
#  -> accuracy = 0.6975, gates = 62.0,recall = 0.735
# String: ...
#  -> accuracy = 0.6775, gates = 69.0,recall = 0.61
# String: ...
#  -> accuracy = 0.7375, gates = 61.0,recall = 0.725
# String: ...
#  -> accuracy = 0.665, gates = 60.0,recall = 0.63
# String: ...
#  -> accuracy = 0.685, gates = 60.0,recall = 0.575
# String: ...
#  -> accuracy = 0.6675, gates = 52.0,recall = 0.66
# String: ...
#  -> accuracy = 0.6575, gates = 57.0,recall = 0.575
# 6  	10    	6  	0.7875	0.710875	0.59  	10    	0.0552736	6  	15.7965	11.5565	9.13095	10    	1.77292
# String: ...
#  -> accuracy = 0.705, gates = 68.0,recall = 0.53
# String: ...
#  -> accuracy = 0.76, gates = 59.0,recall = 0.73
# String: ...
#  -> accuracy = 0.6125, gates = 57.0,recall = 0.56
# String: ...
#  -> accuracy = 0.705, gates = 49.0,recall = 0.695
# String: ...
#  -> accuracy = 0.635, gates = 67.0,recall = 0.565
# String: ...
#  -> accuracy = 0.6225, gates = 67.0,recall = 0.53
# String: ...
#  -> accuracy = 0.615, gates = 67.0,recall = 0.59
# String: ...
#  -> accuracy = 0.69, gates = 66.0,recall = 0.645
# String: ...
#  -> accuracy = 0.665, gates = 53.0,recall = 0.63
# String: ...
#  -> accuracy = 0.68, gates = 62.0,recall = 0.66
# 7  	10    	7  	0.7875	0.725625	0.6575	10    	0.0393373	7  	15.7965	11.6157	9.13095	10    	1.78285
# String: ...
#  -> accuracy = 0.745, gates = 60.0,recall = 0.75
# String: ...
#  -> accuracy = 0.6575, gates = 70.0,recall = 0.615
# String: ...
#  -> accuracy = 0.7, gates = 54.0,recall = 0.65
# String: ...
#  -> accuracy = 0.725, gates = 64.0,recall = 0.67
# String: ...
#  -> accuracy = 0.6575, gates = 62.0,recall = 0.63
# String: ...
#  -> accuracy = 0.6975, gates = 55.0,recall = 0.625
# String: ...
#  -> accuracy = 0.71, gates = 68.0,recall = 0.68
# String: ...
#  -> accuracy = 0.7525, gates = 67.0,recall = 0.76
# String: ...
#  -> accuracy = 0.67, gates = 69.0,recall = 0.665
# String: ...
#  -> accuracy = 0.7025, gates = 75.0,recall = 0.65
# 8  	10    	8  	0.7875	0.72975 	0.6575	10    	0.0383071	8  	15.7965	11.6263	9.13095	10    	1.84582
# String: ...
#  -> accuracy = 0.7325, gates = 74.0,recall = 0.71
# String: ...
#  -> accuracy = 0.7275, gates = 71.0,recall = 0.68
# String: ...
#  -> accuracy = 0.6175, gates = 62.0,recall = 0.515
# String: ...
#  -> accuracy = 0.75, gates = 66.0,recall = 0.71
# String: ...
#  -> accuracy = 0.755, gates = 59.0,recall = 0.675
# String: ...
#  -> accuracy = 0.7375, gates = 53.0,recall = 0.67
# String: ...
#  -> accuracy = 0.6525, gates = 56.0,recall = 0.66
# String: ...
#  -> accuracy = 0.7025, gates = 52.0,recall = 0.625
# String: ...
#  -> accuracy = 0.6925, gates = 65.0,recall = 0.6
# String: ...
#  -> accuracy = 0.695, gates = 54.0,recall = 0.68
# 9  	10    	9  	0.7875	0.73625 	0.6575	10    	0.0369417	9  	15.7965	11.7333	9.13095	10    	1.8535
# String: ...
#  -> accuracy = 0.7875, gates = 87.0,recall = 0.775
# String: ...
#  -> accuracy = 0.6975, gates = 58.0,recall = 0.655
# String: ...
#  -> accuracy = 0.6475, gates = 72.0,recall = 0.62
# String: ...
#  -> accuracy = 0.7775, gates = 58.0,recall = 0.68
# String: ...
#  -> accuracy = 0.7875, gates = 64.0,recall = 0.75
# String: ...
#  -> accuracy = 0.7575, gates = 57.0,recall = 0.72
# String: ...
#  -> accuracy = 0.6825, gates = 65.0,recall = 0.555
# String: ...
#  -> accuracy = 0.7025, gates = 66.0,recall = 0.665
# String: ...
#  -> accuracy = 0.71, gates = 65.0,recall = 0.675
# String: ...
#  -> accuracy = 0.7225, gates = 63.0,recall = 0.705
# 10 	10    	10 	0.7875	0.739125	0.6575	10    	0.0418201	10 	17.6192	11.7789	9.13095	10    	2.23785
# String: ...
#  -> accuracy = 0.8125, gates = 67.0,recall = 0.795
# String: ...
#  -> accuracy = 0.755, gates = 74.0,recall = 0.73
# String: ...
#  -> accuracy = 0.76, gates = 63.0,recall = 0.75
# String: ...
#  -> accuracy = 0.5775, gates = 61.0,recall = 0.6
# String: ...
#  -> accuracy = 0.64, gates = 60.0,recall = 0.62
# String: ...
#  -> accuracy = 0.6, gates = 63.0,recall = 0.51
# String: ...
#  -> accuracy = 0.6625, gates = 52.0,recall = 0.64
# String: ...
#  -> accuracy = 0.6625, gates = 59.0,recall = 0.645
# String: ...
#  -> accuracy = 0.66, gates = 62.0,recall = 0.7
# String: ...
#  -> accuracy = 0.7375, gates = 51.0,recall = 0.69
# 11 	10    	11 	0.8125	0.739625	0.6575	10    	0.0469193	11 	17.6192	11.6118	9.13095	10    	2.3216
# String: ...
#  -> accuracy = 0.705, gates = 49.0,recall = 0.695
# String: ...
#  -> accuracy = 0.7775, gates = 80.0,recall = 0.735
# String: ...
#  -> accuracy = 0.65, gates = 58.0,recall = 0.585
# String: ...
#  -> accuracy = 0.71, gates = 72.0,recall = 0.595
# String: ...
#  -> accuracy = 0.7575, gates = 73.0,recall = 0.725
# String: ...
#  -> accuracy = 0.6625, gates = 52.0,recall = 0.56
# String: ...
#  -> accuracy = 0.77, gates = 59.0,recall = 0.745
# String: ...
#  -> accuracy = 0.7625, gates = 59.0,recall = 0.73
# String: ...
#  -> accuracy = 0.7225, gates = 53.0,recall = 0.74
# String: ...
#  -> accuracy = 0.69, gates = 52.0,recall = 0.615
# 12 	10    	12 	0.8125	0.736875	0.6575	10    	0.0444893	12 	15.7965	11.0536	9.13095	10    	1.79382
# String: ...
#  -> accuracy = 0.8025, gates = 64.0,recall = 0.8
# String: ...
#  -> accuracy = 0.695, gates = 49.0,recall = 0.66
# String: ...
#  -> accuracy = 0.5825, gates = 75.0,recall = 0.57
# String: ...
#  -> accuracy = 0.68, gates = 51.0,recall = 0.655
# String: ...
#  -> accuracy = 0.6475, gates = 72.0,recall = 0.65
# String: ...
#  -> accuracy = 0.725, gates = 57.0,recall = 0.66
# String: ...
#  -> accuracy = 0.7375, gates = 51.0,recall = 0.69
# String: ...
#  -> accuracy = 0.6975, gates = 51.0,recall = 0.69
# String: ...
#  -> accuracy = 0.69, gates = 52.0,recall = 0.615
# String: ...
#  -> accuracy = 0.635, gates = 63.0,recall = 0.5
# 13 	10    	13 	0.8125	0.74025 	0.6575	10    	0.0426241	13 	15.7965	11.014 	9.08353	10    	1.88476
# String: ...
#  -> accuracy = 0.615, gates = 51.0,recall = 0.555
# String: ...
#  -> accuracy = 0.7175, gates = 56.0,recall = 0.745
# String: ...
#  -> accuracy = 0.6925, gates = 47.0,recall = 0.665
# String: ...
#  -> accuracy = 0.705, gates = 49.0,recall = 0.695
# String: ...
#  -> accuracy = 0.685, gates = 54.0,recall = 0.795
# String: ...
#  -> accuracy = 0.6875, gates = 52.0,recall = 0.62
# String: ...
#  -> accuracy = 0.7425, gates = 60.0,recall = 0.64
# String: ...
#  -> accuracy = 0.7425, gates = 64.0,recall = 0.705
# String: ...
#  -> accuracy = 0.6925, gates = 53.0,recall = 0.615
# String: ...
#  -> accuracy = 0.6825, gates = 54.0,recall = 0.69
# 14 	10    	14 	0.8125	0.73475 	0.615 	10    	0.0506822	14 	15.7965	10.883 	8.69239	10    	1.99403
# String: ...
#  -> accuracy = 0.79, gates = 65.0,recall = 0.77
# String: ...
#  -> accuracy = 0.625, gates = 51.0,recall = 0.525
# String: ...
#  -> accuracy = 0.705, gates = 49.0,recall = 0.695
# String: ...
#  -> accuracy = 0.615, gates = 51.0,recall = 0.555
# String: ...
#  -> accuracy = 0.68, gates = 64.0,recall = 0.635
# String: ...
#  -> accuracy = 0.6925, gates = 47.0,recall = 0.665
# String: ...
#  -> accuracy = 0.6725, gates = 63.0,recall = 0.64
# String: ...
#  -> accuracy = 0.675, gates = 55.0,recall = 0.605
# String: ...
#  -> accuracy = 0.605, gates = 51.0,recall = 0.575
# String: ...
#  -> accuracy = 0.615, gates = 47.0,recall = 0.54
# 15 	10    	15 	0.8125	0.7255  	0.605 	10    	0.055332 	15 	13.9038	10.3497	8.09707	10    	1.75747
# String: ...
#  -> accuracy = 0.6975, gates = 49.0,recall = 0.675
# String: ...
#  -> accuracy = 0.5475, gates = 60.0,recall = 0.465
# String: ...
#  -> accuracy = 0.6875, gates = 48.0,recall = 0.625
# String: ...
#  -> accuracy = 0.6475, gates = 48.0,recall = 0.615
# String: ...
#  -> accuracy = 0.6675, gates = 52.0,recall = 0.485
# String: ...
#  -> accuracy = 0.6375, gates = 57.0,recall = 0.59
# String: ...
#  -> accuracy = 0.7225, gates = 61.0,recall = 0.67
# String: ...
#  -> accuracy = 0.63, gates = 53.0,recall = 0.595
# String: ...
#  -> accuracy = 0.6775, gates = 66.0,recall = 0.585
# String: ...
#  -> accuracy = 0.6275, gates = 46.0,recall = 0.53
# 16 	10    	16 	0.8125	0.718875	0.615 	10    	0.0545692	16 	13.9038	10.0728	8.0141 	10    	1.83281
# String: ...
#  -> accuracy = 0.6275, gates = 59.0,recall = 0.555
# String: ...
#  -> accuracy = 0.5725, gates = 47.0,recall = 0.535
# String: ...
#  -> accuracy = 0.7125, gates = 59.0,recall = 0.695
# String: ...
#  -> accuracy = 0.775, gates = 62.0,recall = 0.75
# String: ...
#  -> accuracy = 0.6, gates = 60.0,recall = 0.525
# String: ...
#  -> accuracy = 0.7325, gates = 65.0,recall = 0.685
# String: ...
#  -> accuracy = 0.6675, gates = 47.0,recall = 0.64
# String: ...
#  -> accuracy = 0.625, gates = 54.0,recall = 0.62
# String: ...
#  -> accuracy = 0.7075, gates = 61.0,recall = 0.68
# String: ...
#  -> accuracy = 0.76, gates = 66.0,recall = 0.675
# 17 	10    	17 	0.8125	0.714125	0.5725	10    	0.062085 	17 	13.9038	10.0199	7.80057	10    	1.88192
# String: ...
#  -> accuracy = 0.7525, gates = 61.0,recall = 0.7
# String: ...
#  -> accuracy = 0.6225, gates = 48.0,recall = 0.585
# String: ...
#  -> accuracy = 0.73, gates = 62.0,recall = 0.685
# String: ...
#  -> accuracy = 0.71, gates = 67.0,recall = 0.655
# String: ...
#  -> accuracy = 0.6675, gates = 47.0,recall = 0.64
# String: ...
#  -> accuracy = 0.69, gates = 65.0,recall = 0.615
# String: ...
#  -> accuracy = 0.6325, gates = 45.0,recall = 0.59
# String: ...
#  -> accuracy = 0.615, gates = 47.0,recall = 0.54
# String: ...
#  -> accuracy = 0.635, gates = 59.0,recall = 0.55
# String: ...
#  -> accuracy = 0.705, gates = 49.0,recall = 0.695
# 18 	10    	18 	0.8125	0.71275 	0.5725	10    	0.0560742	18 	13.9038	9.83143	7.80057	10    	1.73163
# String: ...
#  -> accuracy = 0.6225, gates = 47.0,recall = 0.51
# String: ...
#  -> accuracy = 0.6, gates = 68.0,recall = 0.525
# String: ...
#  -> accuracy = 0.705, gates = 49.0,recall = 0.695
# String: ...
#  -> accuracy = 0.6725, gates = 72.0,recall = 0.61
# String: ...
#  -> accuracy = 0.6225, gates = 69.0,recall = 0.55
# String: ...
#  -> accuracy = 0.775, gates = 59.0,recall = 0.745
# String: ...
#  -> accuracy = 0.755, gates = 50.0,recall = 0.615
# String: ...
#  -> accuracy = 0.705, gates = 49.0,recall = 0.695
# String: ...
#  -> accuracy = 0.6125, gates = 57.0,recall = 0.575
# String: ...
#  -> accuracy = 0.685, gates = 65.0,recall = 0.685
# 19 	10    	19 	0.8125	0.712   	0.5725	10    	0.0563449	19 	13.9038	9.79629	7.80057	10    	1.73759
# String: ...
#  -> accuracy = 0.64, gates = 60.0,recall = 0.6
# String: ...
#  -> accuracy = 0.715, gates = 52.0,recall = 0.7
# String: ...
#  -> accuracy = 0.6925, gates = 47.0,recall = 0.665
# String: ...
#  -> accuracy = 0.705, gates = 49.0,recall = 0.695
# String: ...
#  -> accuracy = 0.8, gates = 47.0,recall = 0.8
# String: ...
#  -> accuracy = 0.7325, gates = 47.0,recall = 0.67
# String: ...
#  -> accuracy = 0.7175, gates = 68.0,recall = 0.53
# String: ...
#  -> accuracy = 0.6675, gates = 47.0,recall = 0.64
# String: ...
#  -> accuracy = 0.67, gates = 48.0,recall = 0.645
# String: ...
#  -> accuracy = 0.6325, gates = 46.0,recall = 0.565
# 20 	10    	20 	0.8125	0.710625	0.5725	10    	0.0638792	20 	13.9038	9.67828	7.80057	10    	1.80918
# Simulation finished after 461.66094732284546 seconds

# %%
iot_result = pd.read_csv('bank_testdata.csv',header=None)

def ordenar_salidas_pareto(dataframe):
    dataframe.columns=['ind','circ','gates','accuracy']
    dataframe.sort_values(['gates','accuracy'], ascending=[False,False],inplace=True)
    dataframe.reset_index(inplace=True)
    dataframe.pop('index')
    return dataframe

iot_salidas = ordenar_salidas_pareto(iot_result)
iot_salidas # Queremos ver el primer circuito del dataframe yya ordenado por accuracy (mejor ind)
# Out:
#    ind                                               circ      gates  accuracy
# 0    7  0010001111100100001010010000011111110111011100...  13.903809    0.8125
# 1    6  0111000111110100100100101010100011111001010001...  13.152050    0.8025
# 2    5  1111010011100111101010111110100010110000011111...   9.635000    0.8000
# 3    4  1111010011100111101010111110100010110000011111...   9.027268    0.7325
# 4    3  1100110110001011110000011010101110100010010111...   8.692393    0.6925
# 5    2  1111010011100111101010111110100010110000011111...   8.492643    0.6675
# 6    1  1100110110001011110000011010101110100010010111...   7.875316    0.6325
# 7    0  1111010011100111101010111110100010110000011111...   7.800568    0.5725

# %%
from qiskit.circuit import ParameterVector, QuantumCircuit
from qiskit import QuantumRegister

class CircuitConversor2:

    def __init__(self, nqubits, nparameters):
        gates = {}
        for n, suffix in enumerate(['00','01','10','11']):
            angle = np.pi / (2**n)
            gates['000'+suffix] = (self.make_H(), 1.0)
            gates['001'+suffix] = (self.make_cx(), 2.0)
            gates['010'+suffix] = (self.make_id(), 0.0)
            gates['011'+suffix] = (self.make_rx(angle), 1.0)
            gates['100'+suffix] = (self.make_rz(angle), 1.0)
            gates['101'+suffix] = (self.make_id(), 0.0)
            gates['110'+suffix] = (self.make_id(), 0.0)
            gates['111'+suffix] = (self.make_ry(angle), 1.0)
        self.gates = gates
        self.nqubits = nqubits
        self.register = QuantumRegister(nqubits, 'q')
        self.nparameters = nparameters
        self.nqubits = nqubits
        self.x = ParameterVector('x', nparameters)

    def __call__(self, coding_0):
        print(coding_0)
        circuit = QuantumCircuit(self.register)
        k = 0
        cost = 0
        for ndx, z in enumerate(coding_0):
            qubit = ndx % self.nqubits
            target = (ndx + 1) % self.nqubits
            fn, weight = self.gates[z]
            k = fn(circuit, k, qubit, target)
            cost += weight
        for i in range(k, self.nparameters):
            circuit.rz(self.x[i]*0, self.register[0])
        return circuit, cost

    def make_id(self):
        def operation(circuit, k, qubit, target):
            return k
        return operation

    def make_H(self):
        def operation(circuit, k, qubit, target):
            circuit.h(self.register[qubit])
            return k
        return operation

    def make_cx(self):
        def operation(circuit, k, qubit, target):
            circuit.cx(self.register[qubit], self.register[target])
            return k
        return operation

    def make_rx(self, angle):
        def operation(circuit, k, qubit, target):
            circuit.rx(self.x[k%self.nparameters] * angle,
                       self.register[qubit])
            return k+1
        return operation

    def make_ry(self, angle):
        def operation(circuit, k, qubit, target):
            circuit.ry(self.x[k%self.nparameters] * angle,
                       self.register[qubit])
            return k+1
        return operation

    def make_rz(self, angle):
        def operation(circuit, k, qubit, target):
            circuit.rz(self.x[k%self.nparameters] * angle,
                       self.register[qubit])
            return k+1
        return operation

cc = CircuitConversor2(nqubits=nqubits, nparameters=16)
fm, puertas = cc(coding_bits(iot_salidas.circ[0]))
print(puertas)
fm.draw(output='mpl')
# Out:
# ['00100', '01111', '10010', '00010', '10010', '00001', '11111', '10111', '01110', '01000', '00010', '11011', '00100', '11111', '01110', '10001', '11101', '11001', '11011', '01010', '10101', '00011', '10111', '10111', '10101', '11100', '10100', '10110', '00001', '01000', '00011', '00001', '11100', '11110', '11000', '00100', '01110', '00011', '00110', '01110', '11110', '11110', '01000', '11001', '01111', '10010', '10110', '10110', '01000', '10011', '01011', '01000', '01011', '00011', '00111', '10110', '01011', '00010', '11010', '10110', '11010', '11011', '01000', '01001', '01000', '00011', '01111', '10111', '00001', '11001', '10010', '11111', '10011', '01101', '10001', '00110', '00101', '11100', '01011', '00111', '00111', '00001', '11001', '11101', '11101', '10001', '11101', '11001', '11010', '00010', '10000', '01011', '00011', '11000', '11110', '00110']
# 67.0

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, recall_score, accuracy_score
import matplotlib.pyplot as plt

# %%
def featuremap_performance(pop:str,nqubits:int) -> None:
    '''Returns the performance of a feature map on all of the dataset'''
    df_1 = df.sample(frac=1)

    for i in range(8):
        if i == 7:
            bank_data = df_1.iloc[60000:79844]
            break
        bank_data = df_1.iloc[i*10000:i*10000+10000]

        y = bank_data['y'].values
        X = bank_data[['age','job','marital','education','default','balance',
                    'housing','loan','contact','day','month','duration','campaign','pdays','previous','poutcome']].values


        fitness_obj = Fitness(nqubits,16,X,y,debug=True)

        training_features, training_labels, test_features, test_labels = Dataset(X,y)

        model = QSVM(lambda parameters: fitness_obj.cc(pop, parameters)[0],training_features,training_labels)#fitness_obj(pop)

        y_pred = model.predict(test_features)

        cm = confusion_matrix(test_labels, y_pred)

        #cm_display = ConfusionMatrixDisplay(cm).plot()
        ConfusionMatrixDisplay.from_predictions(test_labels, y_pred)
        plt.show()
        recall = recall_score(test_labels, y_pred)
        acc  = accuracy_score(test_labels, y_pred)

        print(f'String = {pop},\n accuracy = {acc}, recall = {recall} for {i+1}th section of the data')
        
    return None

# %%
featuremap_performance(iot_salidas.circ[0],nqubits)
# Out:
# String = ...,
#  accuracy = 0.7815, recall = 0.749 for 1th section of the data
# String = ...,
#  accuracy = 0.8125, recall = 0.8048289738430584 for 2th section of the data
# String = ...,
#  accuracy = 0.814, recall = 0.79313824419778 for 3th section of the data
# String = ...,
#  accuracy = 0.7885, recall = 0.7669322709163346 for 4th section of the data
# String = ...,
#  accuracy = 0.799, recall = 0.7919191919191919 for 5th section of the data
# String = ...,
#  accuracy = 0.7945, recall = 0.7838104639684107 for 6th section of the data
# String = ...,
#  accuracy = 0.792, recall = 0.7783300198807157 for 7th section of the data

# %%
gen = logbook.select("gen")
wc = logbook.chapters["wc"].select("media")
acc = logbook.chapters["acc"].select("media")

import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
plt.figure(dpi = 100)
line1 = ax1.plot(gen, wc ,"b-", label="Average Weight Control")
ax1.set_xlabel("Generation")
ax1.set_ylabel("Weight Control", color="b")
for tl in ax1.get_yticklabels():
    tl.set_color("b")

ax2 = ax1.twinx()
line2 = ax2.plot(gen, acc, "r-", label="Average Accuracy")
ax2.set_ylabel("Accuracy", color="r")
for tl in ax2.get_yticklabels():
    tl.set_color("r")

lns = line1 + line2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc="best")

plt.show()
