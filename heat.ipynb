# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('bank_cleaned.csv')
data = data.drop(columns='Unnamed: 0')

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
plt.figure(figsize=(19,10))
sns.heatmap(data.iloc[:,1:-1].corr(), annot=True,square=1)
plt.show()

# %%
data.iloc[:,1:-1]
# Out:
#              job   marital  education  default      balance   housing  \
# 0       4.000000  1.000000   2.000000      0.0  3036.000000  1.000000
# 1       9.000000  2.000000   1.000000      0.0   945.000000  1.000000
# 2       2.000000  1.000000   1.000000      0.0   918.000000  1.000000
# 3       1.000000  1.000000   3.000000      0.0  2420.000000  1.000000
# 4      11.000000  2.000000   3.000000      0.0   917.000000  0.000000
# ...          ...       ...        ...      ...          ...       ...
# 79839   1.000000  0.046094   2.907811      0.0  1080.829698  0.000000
# 79840   7.629859  2.000000   2.907465      0.0  1264.185070  0.046268
# 79841   1.000000  1.000000   1.000000      0.0  1083.389821  0.935030
# 79842   2.600571  1.000000   1.067047      0.0  1776.661910  0.533524
# 79843   6.680052  2.000000   1.553325      0.0  1543.020079  0.000000
#
#            loan  contact        day     month    duration  campaign  \
# 0      0.000000      0.0   4.000000  8.000000  261.000000  0.000000
# 1      0.000000      0.0   4.000000  8.000000  151.000000  0.000000
# 2      1.000000      0.0   4.000000  8.000000   76.000000  0.000000
# 3      0.000000      0.0   4.000000  8.000000   92.000000  0.000000
# 4      0.000000      0.0   4.000000  8.000000  198.000000  0.000000
# ...         ...      ...        ...       ...         ...       ...
# 79839  0.000000      0.0   9.769528  5.769528  963.663264  1.000000
# 79840  0.046268      0.0   4.601479  8.000000  442.444789  2.861197
# 79841  0.935030      0.0  11.389821  7.805090  610.440717  0.389821
# 79842  0.533524      0.0  13.002854  4.734665  973.726103  0.533524
# 79843  0.000000      0.0   7.680052  3.213298  324.726466  2.000000
#
#            pdays  previous  poutcome
# 0        0.00000  0.000000  0.000000
# 1        0.00000  0.000000  0.000000
# 2        0.00000  0.000000  0.000000
# 3        0.00000  0.000000  0.000000
# 4        0.00000  0.000000  0.000000
# ...          ...       ...       ...
# 79839    0.00000  0.000000  0.000000
# 79840    0.00000  0.000000  0.000000
# 79841    0.00000  0.000000  0.000000
# 79842    0.00000  0.000000  0.000000
# 79843  185.19322  1.553325  0.893351
#
# [79844 rows x 15 columns]

# %%
# copy the data
df_min_max_scaled = data.copy()
  
# apply normalization techniques
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
  
# view normalized data
print(df_min_max_scaled)
# Out:
#             age       job   marital  education  default   balance   housing  \
# 0      0.526316  0.363636  0.500000   0.666667      0.0  0.423608  1.000000
# 1      0.342105  0.818182  1.000000   0.333333      0.0  0.131854  1.000000
# 2      0.197368  0.181818  0.500000   0.333333      0.0  0.128087  1.000000
# 3      0.381579  0.090909  0.500000   1.000000      0.0  0.337659  1.000000
# 4      0.197368  1.000000  1.000000   1.000000      0.0  0.127948  0.000000
# ...         ...       ...       ...        ...      ...       ...       ...
# 79839  0.223078  0.090909  0.023047   0.969270      0.0  0.150806  0.000000
# 79840  0.006088  0.693624  1.000000   0.969155      0.0  0.176390  0.046268
# 79841  0.266912  0.090909  0.500000   0.333333      0.0  0.151164  0.935030
# 79842  0.298221  0.236416  0.500000   0.355682      0.0  0.247895  0.533524
# 79843  0.148947  0.607277  1.000000   0.517775      0.0  0.215295  0.000000
#
#            loan  contact       day     month  duration  campaign     pdays  \
# 0      0.000000      0.0  0.133333  0.727273  0.166031  0.000000  0.000000
# 1      0.000000      0.0  0.133333  0.727273  0.096056  0.000000  0.000000
# 2      1.000000      0.0  0.133333  0.727273  0.048346  0.000000  0.000000
# 3      0.000000      0.0  0.133333  0.727273  0.058524  0.000000  0.000000
# 4      0.000000      0.0  0.133333  0.727273  0.125954  0.000000  0.000000
# ...         ...      ...       ...       ...       ...       ...       ...
# 79839  0.000000      0.0  0.325651  0.524503  0.613017  0.021277  0.000000
# 79840  0.046268      0.0  0.153383  0.727273  0.281453  0.060877  0.000000
# 79841  0.935030      0.0  0.379661  0.709554  0.388321  0.008294  0.000000
# 79842  0.533524      0.0  0.433428  0.430424  0.619419  0.011352  0.000000
# 79843  0.000000      0.0  0.256002  0.292118  0.206569  0.042553  0.331887
#
#        previous  poutcome    y
# 0      0.000000  0.000000  0.0
# 1      0.000000  0.000000  0.0
# 2      0.000000  0.000000  0.0
# 3      0.000000  0.000000  0.0
# 4      0.000000  0.000000  0.0
# ...         ...       ...  ...
# 79839  0.000000  0.000000  1.0
# 79840  0.000000  0.000000  1.0
# 79841  0.000000  0.000000  1.0
# 79842  0.000000  0.000000  1.0
# 79843  0.038833  0.446675  1.0
#
# [79844 rows x 17 columns]

# %%
df_min_max_scaled
# Out:
#             age       job   marital  education  default   balance   housing  \
# 0      0.526316  0.363636  0.500000   0.666667      0.0  0.423608  1.000000
# 1      0.342105  0.818182  1.000000   0.333333      0.0  0.131854  1.000000
# 2      0.197368  0.181818  0.500000   0.333333      0.0  0.128087  1.000000
# 3      0.381579  0.090909  0.500000   1.000000      0.0  0.337659  1.000000
# 4      0.197368  1.000000  1.000000   1.000000      0.0  0.127948  0.000000
# ...         ...       ...       ...        ...      ...       ...       ...
# 79839  0.223078  0.090909  0.023047   0.969270      0.0  0.150806  0.000000
# 79840  0.006088  0.693624  1.000000   0.969155      0.0  0.176390  0.046268
# 79841  0.266912  0.090909  0.500000   0.333333      0.0  0.151164  0.935030
# 79842  0.298221  0.236416  0.500000   0.355682      0.0  0.247895  0.533524
# 79843  0.148947  0.607277  1.000000   0.517775      0.0  0.215295  0.000000
#
#            loan  contact       day     month  duration  campaign     pdays  \
# 0      0.000000      0.0  0.133333  0.727273  0.166031  0.000000  0.000000
# 1      0.000000      0.0  0.133333  0.727273  0.096056  0.000000  0.000000
# 2      1.000000      0.0  0.133333  0.727273  0.048346  0.000000  0.000000
# 3      0.000000      0.0  0.133333  0.727273  0.058524  0.000000  0.000000
# 4      0.000000      0.0  0.133333  0.727273  0.125954  0.000000  0.000000
# ...         ...      ...       ...       ...       ...       ...       ...
# 79839  0.000000      0.0  0.325651  0.524503  0.613017  0.021277  0.000000
# 79840  0.046268      0.0  0.153383  0.727273  0.281453  0.060877  0.000000
# 79841  0.935030      0.0  0.379661  0.709554  0.388321  0.008294  0.000000
# 79842  0.533524      0.0  0.433428  0.430424  0.619419  0.011352  0.000000
# 79843  0.000000      0.0  0.256002  0.292118  0.206569  0.042553  0.331887
#
#        previous  poutcome    y
# 0      0.000000  0.000000  0.0
# 1      0.000000  0.000000  0.0
# 2      0.000000  0.000000  0.0
# 3      0.000000  0.000000  0.0
# 4      0.000000  0.000000  0.0
# ...         ...       ...  ...
# 79839  0.000000  0.000000  1.0
# 79840  0.000000  0.000000  1.0
# 79841  0.000000  0.000000  1.0
# 79842  0.000000  0.000000  1.0
# 79843  0.038833  0.446675  1.0
#
# [79844 rows x 17 columns]

# %%
plt.figure(figsize=(19,10))
sns.heatmap(data.iloc[:,1:-1].corr(), annot=True)
plt.show()
